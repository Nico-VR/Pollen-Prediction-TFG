# %% [markdown]
# # 3.1 Evaluate models
#
# In the following notebook we will evaluate the predictions of all models by evaluating how well estimate the **Main Pollen Season** (MPS) first. To obtain the MPS, we use two alternative formulas: a percentage-based approach and a threshold-based approach. These functions will be used to compare the predicted MPS periods against the true observed (real) values, and the results will be summarized in a comparison table.
#
# The evaluate generates a CSV file with metrics, which will serve as the basis for a comparison (benchmark).

# %% [markdown]
# ## 1. Environment configuration
# To **import the Python modules that we have created locally in the project** we do the following:

# %%
import sys
from pathlib import Path

# path to the notebook
notebook_path = Path().resolve()

# path to the project root (path to ppf)
project_path = notebook_path.parents[0]

# path to the directory where is placed the source code of the project  (path to ppf/src/ppf/)
code_project_path = notebook_path.parents[0] / 'src'  / 'ppf'

# insert the paths where to search for python modules (import)
sys.path.insert(0, str(code_project_path))

# %% [markdown]
# ## 2. Obtain models benchmark
# ### 2.1 Arguments for the bencmark

# %%
# 1 week of horizon
HORIZON_SIZE = 7

# 1 year of context
INPUT_SIZE = 365 

# evaluation for 1999, 2000, ..., 2022, 2023 (24 years)
START_YEAR = 2000
END_YEAR = 2022

# half a yar of offset days
OFFSET_DAYS = -182

# Output directory of evaluation and predictions
DIR = "../outputs"

# %% [markdown]
# ### 2.2 Get the pollen time series
# 1. Let's load the datset and set the "date" column as the index

# %%
import pandas as pd
# Load the dataset
df = pd.read_csv("../datasets/AlnusOurense9322.csv")

# Set the "date" column as the index
df["date"] = pd.to_datetime(df["date"], format="%d-%m-%Y")
df.set_index("date", inplace=True)

# %% [markdown]
# 2. Get the pollen time series from the dataset (en, endogenous)

# %%
# Get the pandas.Series pollen and filters the data by years 
en = df["pollen"]

# Force daily frequency
en = en.asfreq("D")

# %% [markdown]
# ### 2.3 Run the benchmark using the mps by percentage formula

# %%
from get_evaluations import evaluate

df_evaluate = evaluate(
    start_year=START_YEAR,
    end_year=END_YEAR,
    en=en,
    input_size=INPUT_SIZE,
    horizon_size=HORIZON_SIZE,
    offset_days=OFFSET_DAYS,
    apply_percentage=True,
    start_pct=0.025,
    end_pct=0.975,
    predictions_dir = DIR + '/predictions' ,
    evaluations_dir= DIR + '/evaluations'
)

df_evaluate
# Out:
# Processing year 2000...
# Processing year 2001...
# Processing year 2002...
# Processing year 2003...
# Processing year 2004...
# Processing year 2005...
# Processing year 2006...
# Processing year 2007...
# Processing year 2008...
# Processing year 2009...
# Processing year 2010...
# Processing year 2011...
# Processing year 2012...
# Processing year 2013...
# Processing year 2014...
# Processing year 2015...
# Processing year 2016...
# Processing year 2017...
# Processing year 2018...
# Processing year 2019...
# Processing year 2020...
# Processing year 2021...
# Processing year 2022...
# ✅ Evaluation complete. Saved to: ../outputs/evaluations/mps_evaluation_percentage_2000-2022_-182_365_7_0.025_0.975.csv
#       year                     model_name  uses_covariates  train_size  \
# 0     2000  chronos.conservative.t5.large            False           0
# 1     2000  chronos.conservative.t5.large            False           0
# 2     2000  chronos.conservative.t5.large            False           0
# 3     2000  chronos.conservative.t5.large            False           0
# 4     2000  chronos.conservative.t5.large            False           0
# ...    ...                            ...              ...         ...
# 6274  2022        moirai.stochastic.small            False           0
# 6275  2022        moirai.stochastic.small            False           0
# 6276  2022        moirai.stochastic.small            False           0
# 6277  2022        moirai.stochastic.small            False           0
# 6278  2022        moirai.stochastic.small            False           0
#
#       pred_n      start   end_date  est_start    est_end  start_dev  end_dev  \
# 0          1 2000-01-09 2000-09-01 2000-01-31 2000-02-17         22      197
# 1          2 2000-01-09 2000-09-01 2000-02-01 2000-02-15         23      199
# 2          3 2000-01-09 2000-09-01 2000-02-02 2000-02-16         24      198
# 3          4 2000-01-09 2000-09-01 2000-02-03 2000-02-14         25      200
# 4          5 2000-01-09 2000-09-01 2000-02-04 2000-02-15         26      199
# ...      ...        ...        ...        ...        ...        ...      ...
# 6274       3 2022-01-03 2022-03-06 2021-07-20 2022-12-14        167      283
# 6275       4 2022-01-03 2022-03-06 2021-07-27 2022-12-07        160      276
# 6276       5 2022-01-03 2022-03-06 2021-07-28 2022-12-25        159      294
# 6277       6 2022-01-03 2022-03-06 2021-08-02 2022-12-02        154      271
# 6278       7 2022-01-03 2022-03-06 2021-07-16 2022-12-01        171      270
#
#       duration  est_duration  total_dev  duration_dev
# 0          236            17        219           219
# 1          236            14        222           222
# 2          236            14        222           222
# 3          236            11        225           225
# 4          236            11        225           225
# ...        ...           ...        ...           ...
# 6274        62           512        450          -450
# 6275        62           498        436          -436
# 6276        62           515        453          -453
# 6277        62           487        425          -425
# 6278        62           503        441          -441
#
# [6279 rows x 15 columns]
#       year                    model_name  uses_covariates  train_size  pred_n  \
# 0     2000  chronos.stochastic.bolt.mini            False           0       1
# 1     2000  chronos.stochastic.bolt.mini            False           0       2
# 2     2000  chronos.stochastic.bolt.mini            False           0       3
# 3     2000  chronos.stochastic.bolt.mini            False           0       4
# 4     2000  chronos.stochastic.bolt.mini            False           0       5
# ...    ...                           ...              ...         ...     ...
# 1507  2002    chronos.stochastic.t5.tiny            False           0       3
# 1508  2002    chronos.stochastic.t5.tiny            False           0       4
# 1509  2002    chronos.stochastic.t5.tiny            False           0       5
# 1510  2002    chronos.stochastic.t5.tiny            False           0       6
# 1511  2002    chronos.stochastic.t5.tiny            False           0       7
#
#           start   end_date  est_start    est_end  start_dev  end_dev  \
# 0    2000-01-09 2000-09-01 1999-08-31 2000-10-03        131       32
# 1    2000-01-09 2000-09-01 1999-08-14 2000-09-14        148       13
# 2    2000-01-09 2000-09-01 1999-08-16 2000-09-03        146        2
# 3    2000-01-09 2000-09-01 1999-08-19 2000-08-30        143        2
# 4    2000-01-09 2000-09-01 1999-08-17 2000-09-01        145        0
# ...         ...        ...        ...        ...        ...      ...
# 1507 2002-01-15 2002-12-29 2002-01-19 2002-02-19          4      313
# 1508 2002-01-15 2002-12-29 2002-01-20 2002-02-19          5      313
# 1509 2002-01-15 2002-12-29 2002-01-21 2002-02-20          6      312
# 1510 2002-01-15 2002-12-29 2002-01-22 2002-02-21          7      311
# 1511 2002-01-15 2002-12-29 2002-01-23 2002-02-22          8      310
#
#       duration  est_duration  total_dev  duration_dev
# 0          236           399        163          -163
# 1          236           397        161          -161
# 2          236           384        148          -148
# 3          236           377        145          -141
# 4          236           381        145          -145
# ...        ...           ...        ...           ...
# 1507       348            31        317           317
# 1508       348            30        318           318
# 1509       348            30        318           318
# 1510       348            30        318           318
# 1511       348            30        318           318
#
# [1512 rows x 15 columns]

# %% [markdown]
# ### 2.3 Run the benchmark using the mps by threshold formula

# %%
from get_evaluations import evaluate

df_evaluate = evaluate(
    start_year=START_YEAR,
    end_year=END_YEAR,
    en=en,
    input_size=INPUT_SIZE,
    horizon_size=HORIZON_SIZE,
    offset_days=OFFSET_DAYS,
    apply_percentage=False,
    threshold = 3, 
    consecutive_days = 3,
    predictions_dir = DIR + '/predictions' ,
    evaluations_dir= DIR + '/evaluations'
)

df_evaluate
# Out:
# Processing year 2000...
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.base_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.base_0_365_7_without_covariates.csv, step 7, skip.
# Processing year 2001...
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.tiny_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.tiny_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.tiny_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 1, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 2, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.small_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.small_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.small_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.tiny_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.tiny_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.tiny_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.tiny_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.tiny_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.tiny_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.tiny_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.tiny_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.large_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.large_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.large_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.large_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.large_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.large_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.large_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.small_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.small_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.small_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.base_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.base_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.base_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.base_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.base_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.base_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.base_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.base_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.base_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.base_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.mini_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.tiny_0_365_7_without_covariates.csv, step 2, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.tiny_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.tiny_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.tiny_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.tiny_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 1, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 2, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.t5.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.tiny_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.tiny_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.bolt.tiny_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 2, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.small_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.mini_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.mini_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 1, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 2, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.small_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.small_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.small_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.small_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.small_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.conservative.bolt.small_0_365_7_without_covariates.csv, step 7, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.base_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.auto.t5.base_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.base_0_365_7_without_covariates.csv, step 3, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.base_0_365_7_without_covariates.csv, step 4, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.base_0_365_7_without_covariates.csv, step 5, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.base_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.bolt.base_0_365_7_without_covariates.csv, step 7, skip.
# Processing year 2002...
# Processing year 2003...
# Processing year 2004...
# Processing year 2005...
# Processing year 2006...
# Processing year 2007...
# Processing year 2008...
# Processing year 2009...
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.mini_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.base_0_365_7_without_covariates.csv, step 6, skip.
# ⚠️ Incomplete predicted MPS in ../outputs/predictions/chronos.stochastic.t5.base_0_365_7_without_covariates.csv, step 7, skip.
# Processing year 2010...
# Processing year 2011...
# Processing year 2012...
# Processing year 2013...
# Processing year 2014...
# Processing year 2015...
# Processing year 2016...
# Processing year 2017...
# Processing year 2018...
# Processing year 2019...
# Processing year 2020...
# Processing year 2021...
# Processing year 2022...
# ✅ Evaluation complete. Saved to: ../outputs/evaluations/mps_evaluation_threshold_2000-2022_-182_365_7_3_3.csv
#       year                     model_name  uses_covariates  train_size  \
# 0     2000  chronos.conservative.t5.large            False           0
# 1     2000  chronos.conservative.t5.large            False           0
# 2     2000  chronos.conservative.t5.large            False           0
# 3     2000  chronos.conservative.t5.large            False           0
# 4     2000  chronos.conservative.t5.large            False           0
# ...    ...                            ...              ...         ...
# 6274  2022        moirai.stochastic.small            False           0
# 6275  2022        moirai.stochastic.small            False           0
# 6276  2022        moirai.stochastic.small            False           0
# 6277  2022        moirai.stochastic.small            False           0
# 6278  2022        moirai.stochastic.small            False           0
#
#       pred_n      start   end_date  est_start    est_end  start_dev  end_dev  \
# 0          1 2000-01-17 2000-02-16 2000-01-31 2000-02-14       14.0      2.0
# 1          2 2000-01-17 2000-02-16 2000-02-01 2000-02-15       15.0      1.0
# 2          3 2000-01-17 2000-02-16 2000-02-02 2000-02-10       16.0      6.0
# 3          4 2000-01-17 2000-02-16 2000-02-03 2000-02-11       17.0      5.0
# 4          5 2000-01-17 2000-02-16 2000-02-04 2000-02-12       18.0      4.0
# ...      ...        ...        ...        ...        ...        ...      ...
# 6274       3 2021-12-29 2022-02-26 2021-07-08 2022-12-31      174.0    308.0
# 6275       4 2021-12-29 2022-02-26 2021-07-10 2022-12-31      172.0    308.0
# 6276       5 2021-12-29 2022-02-26 2021-07-04 2022-12-28      178.0    305.0
# 6277       6 2021-12-29 2022-02-26 2021-07-10 2022-12-30      172.0    307.0
# 6278       7 2021-12-29 2022-02-26 2021-07-04 2022-12-30      178.0    307.0
#
#       duration  est_duration  total_dev  duration_dev
# 0           30          14.0       16.0          16.0
# 1           30          14.0       16.0          16.0
# 2           30           8.0       22.0          22.0
# 3           30           8.0       22.0          22.0
# 4           30           8.0       22.0          22.0
# ...        ...           ...        ...           ...
# 6274        59         541.0      482.0        -482.0
# 6275        59         539.0      480.0        -480.0
# 6276        59         542.0      483.0        -483.0
# 6277        59         538.0      479.0        -479.0
# 6278        59         544.0      485.0        -485.0
#
# [6279 rows x 15 columns]
#       year                    model_name  uses_covariates  train_size  pred_n  \
# 0     2000  chronos.stochastic.bolt.mini            False           0       1
# 1     2000  chronos.stochastic.bolt.mini            False           0       2
# 2     2000  chronos.stochastic.bolt.mini            False           0       3
# 3     2000  chronos.stochastic.bolt.mini            False           0       4
# 4     2000  chronos.stochastic.bolt.mini            False           0       5
# ...    ...                           ...              ...         ...     ...
# 1507  2002    chronos.stochastic.t5.tiny            False           0       3
# 1508  2002    chronos.stochastic.t5.tiny            False           0       4
# 1509  2002    chronos.stochastic.t5.tiny            False           0       5
# 1510  2002    chronos.stochastic.t5.tiny            False           0       6
# 1511  2002    chronos.stochastic.t5.tiny            False           0       7
#
#           start   end_date  est_start    est_end  start_dev  end_dev  \
# 0    2000-01-17 2000-02-16 2000-01-31 2000-02-17       14.0      1.0
# 1    2000-01-17 2000-02-16 2000-02-01 2000-02-12       15.0      4.0
# 2    2000-01-17 2000-02-16 2000-02-02 2000-02-13       16.0      3.0
# 3    2000-01-17 2000-02-16 2000-02-03 2000-02-14       17.0      2.0
# 4    2000-01-17 2000-02-16 2000-02-04 2000-02-15       18.0      1.0
# ...         ...        ...        ...        ...        ...      ...
# 1507 2002-01-15 2002-12-25 2002-01-18 2002-02-19        3.0    309.0
# 1508 2002-01-15 2002-12-25 2002-01-19 2002-02-20        4.0    308.0
# 1509 2002-01-15 2002-12-25 2002-01-20 2002-02-21        5.0    307.0
# 1510 2002-01-15 2002-12-25 2002-01-21 2002-02-22        6.0    306.0
# 1511 2002-01-15 2002-12-25 2002-01-22 2002-02-23        7.0    305.0
#
#       duration  est_duration  total_dev  duration_dev
# 0           30          17.0       15.0          13.0
# 1           30          11.0       19.0          19.0
# 2           30          11.0       19.0          19.0
# 3           30          11.0       19.0          19.0
# 4           30          11.0       19.0          19.0
# ...        ...           ...        ...           ...
# 1507       344          32.0      312.0         312.0
# 1508       344          32.0      312.0         312.0
# 1509       344          32.0      312.0         312.0
# 1510       344          32.0      312.0         312.0
# 1511       344          32.0      312.0         312.0
#
# [1512 rows x 15 columns]

# %% [markdown]
# ➡️ **[Next notebook: 03-02_Benchmark_without_covariates](../notebooks/03-02_Benchmark_without_covariates.ipynb)**
